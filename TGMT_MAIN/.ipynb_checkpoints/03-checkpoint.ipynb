# %%
# !pip install Pillow

# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path = 'C:/Users/ADMIN/OneDrive/Documents/crs/img/01/1.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (197, 256)

# %%
# Thay đổi kích thước
new_size = (900,900)
new_image = img.resize(new_size)
display(new_image)
#lưu xuống ổ đĩa 
new_image.save('C:/Users/ADMIN/OneDrive/Documents/crs/img/01/resized_image.png')
# Out:
# <PIL.Image.Image image mode=P size=900x900>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task:
new_image.save('C:/Users/ADMIN/OneDrive/Documents/crs/img/01/newthumnail_image.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=38x50>
