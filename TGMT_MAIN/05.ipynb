# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\admin\appdata\roaming\python\python312\site-packages (10.4.0)

# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/ADMIN/OneDrive/Documents/crs/img/01/2.png'

# %%
# Đọc ảnh 
img = load_image(my_path)

# Resize
# img = img.resize((250,250))

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=224x225>

# %%
#xoay ảnh 
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=224x225>

# %%
#xoay ảnh 
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=224x225>

# %%
#transpose ảnh hoán đổi vị trí
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=P size=225x224>

# %%
#Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=224x225>
